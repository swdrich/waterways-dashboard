# %%
# Import dependencies

import pandas as pd

# %%
# Set up file paths for csv files

trip_path = "../Static/data/Cedar Lake Van Buren County Two - Sheet1.csv"

trip_data = pd.read_csv(trip_path)
trip_data
# Out:
#        Lake Name     County     State                 SurveyName  \
# 0     Cedar Lake  Van Buren  Michigan               kayak tour 2
# 1     Cedar Lake  Van Buren  Michigan               kayak tour 2
# 2     Cedar Lake  Van Buren  Michigan               kayak tour 2
# 3     Cedar Lake  Van Buren  Michigan               kayak tour 2
# 4     Cedar Lake  Van Buren  Michigan               kayak tour 2
# ...          ...        ...       ...                        ...
# 4745  Cedar Lake  Van Buren  Michigan  Heckamankayakcedarlakevbc
# 4746  Cedar Lake  Van Buren  Michigan  Heckamankayakcedarlakevbc
# 4747  Cedar Lake  Van Buren  Michigan  Heckamankayakcedarlakevbc
# 4748  Cedar Lake  Van Buren  Michigan  Heckamankayakcedarlakevbc
# 4749  Cedar Lake  Van Buren  Michigan  Heckamankayakcedarlakevbc
#
#      Contributor Name  Year  Month  Day     Date Approx Time of Day  \
# 0       D. McLaughlin  2020      4    6   4/6/20           10:02:30
# 1       D. McLaughlin  2020      4    6   4/6/20           10:03:00
# 2       D. McLaughlin  2020      4    6   4/6/20           10:03:30
# 3       D. McLaughlin  2020      4    6   4/6/20           10:04:00
# 4       D. McLaughlin  2020      4    6   4/6/20           10:04:30
# ...               ...   ...    ...  ...      ...                ...
# 4745      D. Heckaman  2020      7   16  7/16/20           16:59:20
# 4746      D. Heckaman  2020      7   16  7/16/20           16:59:30
# 4747      D. Heckaman  2020      7   16  7/16/20           16:59:40
# 4748      D. Heckaman  2020      7   16  7/16/20           16:59:50
# 4749      D. Heckaman  2020      7   16  7/16/20           17:00:00
#
#       Elapsed Time (sec)  Surface Water Temperature (oF)  \
# 0                    150                             NaN
# 1                    180                             NaN
# 2                    210                             NaN
# 3                    240                             NaN
# 4                    270                             NaN
# ...                  ...                             ...
# 4745                4950                            82.5
# 4746                4960                            82.5
# 4747                4970                            82.5
# 4748                4980                            82.5
# 4749                4990                            82.5
#
#       Conductivity (µS/cm)  Latitude  Longitude Location Name Notes
# 0                    319.0  42.08891  -85.82564     Main Lake   NaN
# 1                    323.0  42.08893  -85.82565     Main Lake   NaN
# 2                    324.0  42.08896  -85.82567     Main Lake   NaN
# 3                    326.0  42.08898  -85.82567     Main Lake   NaN
# 4                    326.0  42.08898  -85.82566     Main Lake   NaN
# ...                    ...       ...        ...           ...   ...
# 4745                 291.0  42.08896  -85.82597     Main Lake   NaN
# 4746                 291.0  42.08899  -85.82592     Main Lake   NaN
# 4747                 291.0  42.08900  -85.82587     Main Lake   NaN
# 4748                 291.0  42.08901  -85.82583     Main Lake   NaN
# 4749                 291.0  42.08902  -85.82578     Main Lake   NaN
#
# [4750 rows x 17 columns]
